# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bulk = pd.read_csv('human_bulk_aggregated.csv')
bulk = bulk.set_index('gene')
scel = pd.read_csv('agg_data.csv')
scel = scel.set_index('Unnamed: 0')
scel.index.name = 'gene'

bulk = bulk.loc[list(scel.index)]

d = {}
for i in bulk.index:
    if i not in d:
        d[i] = 1
    else:
        d[i] += 1
drop = []
for g, c in d.items():
    if c>1:
        drop.append(g)

scel = scel.drop(drop,axis=0)
bulk = bulk.drop(drop,axis=0)

norm = lambda x: (x-x.min())/(x.max()-x.min())
dist = lambda x, y: np.linalg.norm(x-y) 

for col in bulk.columns:
    bulk[col] = norm(bulk[col])
for col in scel.columns:
    scel[col] = norm(scel[col])

# %%
ti = scel.columns[0]
tj = bulk.columns[0]

dist(scel[ti],bulk[tj])
# Out:
# 7.994727979910964

# %%
scel
# Out:
#              CS12      CS14      CS17      CS19
# gene
# CYP51A1  0.013683  0.022863  0.007222  0.021108
# LASP1    0.011799  0.016099  0.038923  0.028350
# PLXND1   0.002817  0.001760  0.005949  0.001769
# AP2B1    0.110155  0.188334  0.180565  0.177780
# SEC62    0.209857  0.295299  0.261501  0.332990
# ...           ...       ...       ...       ...
# TPM2     0.180353  0.058098  0.046077  0.028714
# ZBED1    0.020994  0.012667  0.042253  0.030971
# DDX3X    0.089200  0.124401  0.193627  0.158170
# FAM19A5  0.040073  0.056180  0.064541  0.049179
# HNF1B    0.003285  0.000521  0.001143  0.000329
#
# [1448 rows x 4 columns]

# %%
sns.set()
plt.figure(figsize=(18,12))
# axes = fig.subplots(2,2)
# axes = axes.flatten()

cols = ['blue','green','yellow','red']

for i, ti in enumerate(scel.columns):
    sc = scel[ti]
    dists = []
    for j, tj in enumerate(bulk.columns):
        bk = bulk[tj]
        dists.append(dist(sc, bk))
    plt.plot(np.arange(len(dists)),-norm(np.array(dists)), label=ti, color=cols[i])
    plt.xlabel('In Vitro Day')
    plt.ylabel('Normalised Similarity')
plt.legend()
plt.title("Comparing in vitro and in vivo")
plt.show()
